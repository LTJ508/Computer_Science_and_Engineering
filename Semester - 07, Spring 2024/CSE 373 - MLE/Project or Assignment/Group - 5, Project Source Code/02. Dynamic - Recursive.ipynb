# %% [markdown]
# ![image.png](attachment:66d52892-e9c9-434f-8d30-f172194e20d8.png)

# %% [markdown]
# # <font color="red">Coin Change Problem</font>

# %% [markdown]
# ### Importing some essnetial library

# %%
import sys
import time
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Different Coin List and sum value will be used in this project for verification that the algorithm is working perfectly
# ### Coinset we will use for to verify the algorithm

# %%
coinSet1 = [1, 2, 5, 10, 20, 50, 100, 200, 500, 1000] #Bangladesh Currency System
coinSet2 = [1, 5, 10, 25, 50, 100] #US Currency System
coinSet3 = [1, 2, 5, 10, 20, 25] #General Coin Set
coinSet4 = [1, 5, 8, 10] #General Coin Set

# %% [markdown]
# ## For sum we will use to verify the algorithm
# 1. coinSet1 => 211, 35
# 2. coinSet2 => 157, 29
# 3. coinSet3 => 30, 20
# 4. coinSet4 => 14, 13

# %% [markdown]
# # <font color="red">Dynamic Programing - Recursive</font>

# %%
#defining the algorithm
def cashierDynamicRecursive(coins, sum, startIndex):
    global dp #global variable, need to initialize before call this function
    
    if (sum == 0): #base case 1
        return 1
    if (sum < 0 or startIndex >= len(coins)): #base case 2
        return 0
    if(startIndex, sum) in dp: #if previously computed then it will be return
        return dp[(startIndex, sum)]
    
    with_startIndex = cashierDynamicRecursive(coins, sum - coins[startIndex], startIndex) #calling recursively with the starting index
    without_startIndex = cashierDynamicRecursive(coins, sum, startIndex+1) #calling recursively without the starting index

    dp[(startIndex, sum)] = with_startIndex + without_startIndex #storing the computed result for avoiding future computation
    
    return dp[(startIndex, sum)]

# %% [markdown]
# ## Testing for coinSet1

# %%
coins = coinSet1.copy()

# %%
sum = 211
dp = {} #initialize the daynamic memorizing array

start_time = time.time() #time count start
numberOfCombinations = cashierDynamicRecursive(coins, sum, 0)
end_time = time.time() #time count end

print("Number of combinations:", numberOfCombinations)
print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 93057
# Execution time: 0.001000 seconds

# %%
sum = 35
dp = {} #initialize the daynamic memorizing array

start_time = time.time() #time count start
numberOfCombinations = cashierDynamicRecursive(coins, sum, 0)
end_time = time.time() #time count end

print("Number of combinations:", numberOfCombinations)
print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 162
# Execution time: 0.001002 seconds

# %% [markdown]
# ## Testing for coinSet2

# %%
coins = coinSet2.copy()

# %%
sum = 157
dp = {} #initialize the daynamic memorizing array

start_time = time.time() #time count start
numberOfCombinations = cashierDynamicRecursive(coins, sum, 0)
end_time = time.time() #time count end

print("Number of combinations:", numberOfCombinations)
print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 1138
# Execution time: 0.001002 seconds

# %%
sum = 29
dp = {} #initialize the daynamic memorizing array

start_time = time.time() #time count start
numberOfCombinations = cashierDynamicRecursive(coins, sum, 0)
end_time = time.time() #time count end

print("Number of combinations:", numberOfCombinations)
print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 13
# Execution time: 0.000000 seconds

# %% [markdown]
# ## Testing for coinSet3

# %%
coins = coinSet3.copy()

# %%
sum = 30
dp = {} #initialize the daynamic memorizing array

start_time = time.time() #time count start
numberOfCombinations = cashierDynamicRecursive(coins, sum, 0)
end_time = time.time() #time count end

print("Number of combinations:", numberOfCombinations)
print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 113
# Execution time: 0.000000 seconds

# %%
sum = 20
dp = {} #initialize the daynamic memorizing array

start_time = time.time() #time count start
numberOfCombinations = cashierDynamicRecursive(coins, sum, 0)
end_time = time.time() #time count end

print("Number of combinations:", numberOfCombinations)
print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 41
# Execution time: 0.000000 seconds

# %% [markdown]
# ## Testing for coinSet4

# %%
coins = coinSet4.copy()

# %%
sum = 14
dp = {} #initialize the daynamic memorizing array

start_time = time.time() #time count start
numberOfCombinations = cashierDynamicRecursive(coins, sum, 0)
end_time = time.time() #time count end

print("Number of combinations:", numberOfCombinations)
print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 6
# Execution time: 0.000000 seconds

# %%
sum = 13
dp = {} #initialize the daynamic memorizing array

start_time = time.time() #time count start
numberOfCombinations = cashierDynamicRecursive(coins, sum, 0)
end_time = time.time() #time count end

print("Number of combinations:", numberOfCombinations)
print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 6
# Execution time: 0.000000 seconds

# %% [markdown]
# ### So far we have test our algorithm and its working perfectly and matched with other algorithm's output\
# Lets plot the graph to identify the time complexity

# %% [markdown]
# # <font color="red">Plotting Graph</font>

# %% [markdown]
# ## In our problem we have two variable, one is number of coim, another is sum
# Execution time depends on this two variable.\
# So we first fixed a sum amount and check for multiple coin set, identify how its behave with the changing of number of coin in a coinset.\
# Then we fixed a coin set and check for multiple sum amount, identify how this algorithm behave with the changing of sum amount.\
# As our algorithm have two for loop, outer for loop will run O(number of coin) and inner for loop will run O(sum).\
# Therefore, our time complexity will be O(number of coin * sum). Which is linear function.\
# Lets verify with the graph

# %%
#Random Sum value generated randomly by random library, and used in every algorithm for identify the time complexity
random_sum = [148379, 203158, 363103, 457966, 472585, 663706, 741838, 910374, 950201, 978368]

# %%
#Random Coin Set generated randomly by random library, and used in every algorithm for identify the time complexity
CoinSet = [[37, 47, 218, 231, 349, 367, 429, 452, 457, 536, 539, 708, 828, 871, 1000],
           [68, 114, 123, 171, 199, 255, 295, 537, 553, 627, 631, 659, 661, 687, 866, 913, 929, 945, 966],
           [11, 82, 119, 296, 332, 339, 348, 388, 404, 421, 436, 447, 472, 486, 543, 561, 570, 818, 845, 891, 991],
           [25, 56, 84, 223, 341, 375, 401, 410, 452, 464, 514, 517, 520, 535, 559, 596, 720, 760, 785, 814, 829, 831, 857, 866, 893, 895, 912, 933, 953, 993],
           [2, 10, 38, 59, 61, 63, 121, 160, 162, 166, 202, 205, 237, 263, 290, 313, 401, 402, 414, 459, 512, 576, 584, 614, 642, 648, 650, 671, 686, 689, 779, 798, 811, 870, 990],
           [46, 71, 102, 103, 109, 140, 143, 172, 174, 178, 203, 218, 264, 266, 286, 287, 293, 343, 378, 384, 404, 455, 464, 467, 482, 493, 497, 498, 507, 525, 539, 550, 586, 602, 603, 606, 664, 679, 683, 694, 714, 751, 754, 810, 813, 814, 815, 865, 895, 899, 912, 919, 936, 953, 967, 970, 991, 995],
           [3, 16, 21, 39, 47, 50, 86, 89, 104, 110, 129, 135, 166, 184, 217, 227, 253, 256, 264, 296, 313, 324, 351, 354, 360, 361, 382, 395, 468, 479, 481, 483, 488, 496, 498, 509, 527, 537, 562, 571, 582, 583, 599, 610, 641, 642, 644, 649, 669, 671, 682, 725, 734, 745, 782, 816, 834, 847, 862, 892, 896, 898, 904, 914, 917, 935, 937, 941, 949, 987, 989, 998],
           [8, 12, 32, 40, 42, 46, 53, 65, 80, 83, 116, 118, 119, 150, 151, 158, 174, 175, 196, 198, 222, 225, 235, 238, 239, 256, 287, 296, 299, 300, 302, 308, 333, 347, 374, 381, 397, 403, 415, 433, 445, 482, 492, 495, 511, 512, 553, 564, 579, 583, 597, 600, 603, 659, 683, 686, 691, 697, 707, 711, 725, 730, 736, 750, 776, 778, 789, 830, 835, 836, 841, 853, 867, 868, 883, 893, 935, 971, 978, 990, 996, 998],
           [1, 13, 15, 20, 21, 35, 55, 56, 74, 96, 112, 162, 170, 181, 186, 198, 200, 201, 211, 213, 216, 218, 233, 240, 249, 268, 276, 279, 295, 298, 299, 312, 322, 335, 337, 344, 347, 356, 371, 399, 407, 408, 412, 422, 432, 434, 448, 460, 468, 484, 489, 494, 524, 532, 537, 553, 556, 559, 562, 566, 583, 593, 599, 613, 624, 634, 639, 667, 680, 682, 688, 691, 701, 705, 721, 732, 748, 767, 808, 811, 812, 821, 850, 862, 868, 872, 889, 894, 901, 921, 934, 966, 1000],
           [16, 19, 47, 61, 76, 78, 108, 121, 129, 143, 146, 155, 162, 164, 170, 180, 181, 182, 186, 227, 230, 236, 241, 243, 244, 258, 276, 282, 283, 284, 287, 293, 307, 334, 355, 378, 384, 386, 389, 395, 416, 439, 450, 454, 461, 473, 477, 480, 489, 498, 505, 518, 527, 550, 555, 563, 567, 577, 585, 599, 610, 616, 625, 626, 646, 663, 666, 692, 693, 708, 715, 724, 727, 729, 743, 744, 748, 750, 768, 790, 806, 823, 833, 840, 850, 854, 855, 874, 887, 892, 913, 924, 953, 968, 981, 994, 995]]

# %%
#variable that can adjust the plotting parameter
fixed_sum = 978368
coins = CoinSet[9]

# %% [markdown]
# ### Increasing the recursive depth limit

# %%
# Set recursion limit
sys.setrecursionlimit(fixed_sum*10)

# Example recursive function
def recursive_function(n):
    if n <= 0:
        return 0
    return recursive_function(n - 1) + 1

# Test the function
try:
    print(recursive_function(fixed_sum))
except RecursionError as e:
    print("Recursion limit exceeded:", e)
    sys.setrecursionlimit(1000)  # back to a safer default
# Out:
# 978368

# %% [markdown]
# ## This Cell
# will generate the data point for ploting the graph.\
# Here Sum amount is fixed and coinSet is variable

# %%
#declaring two variable for storing the data points
times = []
num_coins = []

#this loop will change the coin set and call the function to calculate the execution time
for coins in CoinSet:
    dp = {} #initialize the daynamic memorizing array
    start_time = time.time() #time count start
    numberOfCombinations = cashierDynamicRecursive(coins, fixed_sum, 0)
    end_time = time.time() #time count end

    #storing the data point for ploting
    times.append(end_time - start_time)
    num_coins.append(len(coins))

    #printing the result info, how its changing
    print("\nNumber of combinations:", numberOfCombinations)
    print("Number of Coins:", len(coins))
    print("Sum:", fixed_sum)
    print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 60579639183304910845663630600400335
# Number of Coins: 15
# Sum: 978368
# Execution time: 16.426877 seconds
#
# Number of combinations: 2010546707470785693486262953767619184268122
# Number of Coins: 19
# Sum: 978368
# Execution time: 21.069382 seconds
#
# Number of combinations: 753777191722714154071293696836099655401389809416
# Number of Coins: 21
# Sum: 978368
# Execution time: 22.965867 seconds
#
# Number of combinations: 239020760844539858733173203704722443447368178682782872117286373
# Number of Coins: 30
# Sum: 978368
# Execution time: 35.710052 seconds
#
# Number of combinations: 816631570331019203894053300048373152414416445083934168692533613230695708946674022
# Number of Coins: 35
# Sum: 978368
# Execution time: 38.521925 seconds
#
# Number of combinations: 26916153087601840039765024537891683906154858150138743411039915152595595167036249714861961679095932572246380465028
# Number of Coins: 58
# Sum: 978368
# Execution time: 81.846026 seconds
#
# Number of combinations: 29305100845364650380117788896937439673723511043737453505189605719497977717829008316250486349837355327352590792979324093248276125490525764313
# Number of Coins: 72
# Sum: 978368
# Execution time: 95.521500 seconds
#
# Number of combinations: 96455924179516868552274015604993129756407529596019855766704966020692918638474672171066776393705887601258506534257321208602356143385881960713591401449753503281
# Number of Coins: 82
# Sum: 978368
# Execution time: 101.293533 seconds
#
# Number of combinations: 26457308237466446704759475673303285028738583950851152038558966892665318902340743245801146025499076855686485839988657229095568807163148935431178667735914642388710154487403723011
# Number of Coins: 93
# Sum: 978368
# Execution time: 137.210986 seconds
#
# Number of combinations: 8751831920466489391846346933747705963614071276116739020713508055521787442043496815198918131244308647082449104773001656852574123162546135628664136659303980904651734932191828662
# Number of Coins: 97
# Sum: 978368
# Execution time: 141.097606 seconds

# %% [markdown]
# ### Ploting a simple line graph with the data point

# %%
#using the matplotlib library
plt.figure(figsize=(10, 6))
plt.plot(num_coins, times, 'o-')
plt.xlabel('Number of Coins in Coin Set')
plt.ylabel('Execution Time (seconds)')
plt.title(f'Execution Time vs. Number of Coins (Sum = {fixed_sum})')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Ploting the Polynomial Fit Graph

# %%
coefficients_polynomial = np.polyfit(num_coins, times, 2) #for quadratic function, where degree is 2
polynomial = np.poly1d(coefficients_polynomial)

# Generate x values for plotting the polynomial
x_poly = np.linspace(min(num_coins), max(num_coins), 500)
y_poly = polynomial(x_poly)

plt.figure(figsize=(10, 6))
plt.plot(num_coins, times, 'o', label='Data Points')
plt.plot(x_poly, y_poly, '-', label=f'Polynomial Fit: {polynomial}')
plt.xlabel('Number of Coins in Coin Set')
plt.ylabel('Execution Time (seconds)')
plt.title(f'Execution Time vs. Number of Coins (Sum = {fixed_sum})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Ploting the Linear Fit Graph
# As we can see the data point are rising as a linear graph

# %%
coefficients_linear = np.polyfit(num_coins, times, 1)
linear = np.poly1d(coefficients_linear)

# Generate x values for plotting the Linear
x_linear = np.linspace(min(num_coins), max(num_coins), 500)
y_linear = linear(x_linear)

plt.figure(figsize=(10, 6))
plt.plot(num_coins, times, 'o', label='Data Points')
plt.plot(x_linear, y_linear, '-', label=f'Linear Fit: {linear}')
plt.xlabel('Number of Coins in Coin Set')
plt.ylabel('Execution Time (seconds)')
plt.title(f'Execution Time vs. Number of Coins (Sum = {fixed_sum})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## This Cell
# will generate the data point for ploting the graph.\
# Here Coin Set is fixed and Sum amount is variable

# %%
#declaring two variable for storing the data points
times = []
sums = []

#this loop will change the coin set and call the function to calculate the execution time
for sum_value in random_sum:
    dp = {} #initialize the daynamic memorizing array
    start_time = time.time() #time count start
    numberOfCombinations = cashierDynamicRecursive(coins, sum_value, 0)
    end_time = time.time() #time count end

    #storing the data point for ploting
    times.append(end_time - start_time)
    sums.append(sum_value)

    #printing the result info, how its changing
    print("\nNumber of combinations:", numberOfCombinations)
    print("Number of Coins:", len(coins))
    print("Sum:", sum_value)
    print("Execution time: {:.6f} seconds".format(end_time - start_time))
# Out:
# Number of combinations: 240757149090033854766813551281248974795999066638965443478303970668782503117961040641196933917329689793
# Number of Coins: 97
# Sum: 148379
# Execution time: 18.468294 seconds
#
# Number of combinations: 91063691027158496146505230737294985737521763242779178489313570484772205826974904361371448611203977576936752799738
# Number of Coins: 97
# Sum: 203158
# Execution time: 23.953040 seconds
#
# Number of combinations: 1766434196593796169037882380960112364598714000823676757001332536373893582279156598961376594950632167190434248143750595349227056403268785
# Number of Coins: 97
# Sum: 363103
# Execution time: 44.978028 seconds
#
# Number of combinations: 2494841411622806060958669945213078806993741469081629855308593887645536206244437453189811330029685606192952603572286719920812726825128375117470338
# Number of Coins: 97
# Sum: 457966
# Execution time: 57.420830 seconds
#
# Number of combinations: 44063779575069297406354320526334620194352083127925204861725276274582176761324046045639508776599522892406185819663766753454234332795564672996981562
# Number of Coins: 97
# Sum: 472585
# Execution time: 60.133917 seconds
#
# Number of combinations: 1693668209535901563713042781990443503648935730128107813134521518046905169124268964227865642637341082881380317756255347279222739299243523660815994845868148353665
# Number of Coins: 97
# Sum: 663706
# Execution time: 83.682716 seconds
#
# Number of combinations: 52151777920593720909306754576903030477792761491221955635731784679510253902189411416252954559098973865832447636430612765061431063342788090287206985173580707797573484
# Number of Coins: 97
# Sum: 741838
# Execution time: 96.059953 seconds
#
# Number of combinations: 10298536375421547787999434433810364249081622842410355206568188493131668976234678550115949882244890667684675349231080253284804029624840422020533371015535257686488044039770260
# Number of Coins: 97
# Sum: 910374
# Execution time: 119.454623 seconds
#
# Number of combinations: 566862605004510755228891748652822055080537497240575701829616487802997580782682513459305473346969183692771529049306313583060862409856177625966512548679031464703273380273933688
# Number of Coins: 97
# Sum: 950201
# Execution time: 139.424352 seconds
#
# Number of combinations: 8751831920466489391846346933747705963614071276116739020713508055521787442043496815198918131244308647082449104773001656852574123162546135628664136659303980904651734932191828662
# Number of Coins: 97
# Sum: 978368
# Execution time: 147.645548 seconds

# %% [markdown]
# ### Ploting a simple line graph with the data point

# %%
#using the matplotlib library
plt.figure(figsize=(10, 6))
plt.plot(sums, times, 'o-')
plt.xlabel('Sum Value')
plt.ylabel('Execution Time (seconds)')
plt.title(f'Execution Time vs. Sum Value') # (Coin Set = {coins})
plt.grid(True)
plt.show()

# %% [markdown]
# ### Ploting the Polynomial Fit Graph

# %%
coefficients_polynomial = np.polyfit(sums, times, 2)
polynomial = np.poly1d(coefficients_polynomial)

# Generate x values for plotting the polynomial
x_poly = np.linspace(min(sums), max(sums), 500)
y_poly = polynomial(x_poly)

plt.figure(figsize=(10, 6))
plt.plot(sums, times, 'o', label='Data Points')
plt.plot(x_poly, y_poly, '-', label=f'Polynomial Fit: {polynomial}')
plt.xlabel('Sum Value')
plt.ylabel('Execution Time (seconds)')
plt.title(f'Execution Time vs. Sum Value') # (Coin Set = {coins})
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Ploting the Linear Fit Graph
# As we can see the data point are rising as a linear graph

# %%
coefficients_linear = np.polyfit(sums, times, 1)
linear = np.poly1d(coefficients_linear)

# Generate x values for plotting the polynomial
x_linear = np.linspace(min(sums), max(sums), 500)
y_linear = linear(x_linear)

plt.figure(figsize=(10, 6))
plt.plot(sums, times, 'o', label='Data Points')
plt.plot(x_linear, y_linear, '-', label=f'Linear Fit: {linear}')
plt.xlabel('Sum Value')
plt.ylabel('Execution Time (seconds)')
plt.title(f'Execution Time vs. Sum Value') # (Coin Set = {coins})
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Reseting the recursive depth

# %%
sys.setrecursionlimit(1000)  # back to a safer default

# %% [markdown]
# # Therefore, Both cases, time complexity provide a linear graph.
# # So the total time complexity will be O(number of Coin * Sum amount)

# %% [markdown]
# # <center><font size="50" color="red">Thank You</font></center>
